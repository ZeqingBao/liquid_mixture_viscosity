# %%
import pandas as pd

# %%
data_prefix = 'data_cleaned/'

train_df = pd.read_csv(data_prefix + 'data.csv')
train_feat_df = pd.read_csv(data_prefix + 'data_features.csv')

test_df = pd.read_csv(data_prefix + 'test.csv')
test_feat_df = pd.read_csv(data_prefix + 'test_features.csv')

# %%
# combine features with original data horizontally
train_combined_df = pd.concat([train_df, train_feat_df], axis=1)
train_combined_df['benchmark'] = 'train'

test_combined_df = pd.concat([test_df, test_feat_df], axis=1)
test_combined_df['benchmark'] = 'test'

original_data = pd.concat([train_combined_df, test_combined_df], axis=0).reset_index(drop=True)
original_data['type'] = 'original'

# %%
# build alphabetical pair key for each mixture
original_data['combos'] = original_data.apply(
    lambda row: '-'.join(sorted([row['MOL_1'], row['MOL_2']])),
    axis=1
)

# %%
original_data.head(20)
# Out:
#              MOL_1        MOL_2      logV  MolFrac_1       T benchmark  \
# 0      B(Br)(Br)Br          CCO -0.140112        1.0  298.00     train
# 1             BrBr          CCO -0.011187        1.0  298.00     train
# 2    BrC(Br)(Br)Br     c1ccccc1 -0.219755        0.0  298.15     train
# 3    BrC(Br)(Br)Br     c1ccccc1 -0.080765        0.1  298.15     train
# 4    BrC(Br)(Br)Br     c1ccccc1  0.050070        0.2  298.15     train
# 5    BrC(Br)(Br)Br     c1ccccc1  0.165422        0.3  298.15     train
# 6    BrC(Br)(Br)Br     c1ccccc1  0.264700        0.4  298.15     train
# 7    BrC(Br)(Br)Br     c1ccccc1  0.349316        0.5  298.15     train
# 8    BrC(Br)(Br)Br     c1ccccc1  0.420879        0.6  298.15     train
# 9    BrC(Br)(Br)Br     c1ccccc1  0.480840        0.7  298.15     train
# 10   BrC(Br)(Br)Br     c1ccccc1  0.530328        0.8  298.15     train
# 11   BrC(Br)(Br)Br     c1ccccc1  0.570099        0.9  298.15     train
# 12   BrC(Br)(Br)Br     c1ccccc1  0.600592        1.0  298.15     train
# 13  BrC(Br)C(Br)Br  CCCCCCCCCCO  0.985696        0.0  303.15     train
# 14  BrC(Br)C(Br)Br  CCCCCCCCCCO  0.975610        0.1  303.15     train
# 15  BrC(Br)C(Br)Br  CCCCCCCCCCO  0.966143        0.2  303.15     train
# 16  BrC(Br)C(Br)Br  CCCCCCCCCCO  0.956663        0.3  303.15     train
# 17  BrC(Br)C(Br)Br  CCCCCCCCCCO  0.947683        0.4  303.15     train
# 18  BrC(Br)C(Br)Br  CCCCCCCCCCO  0.939620        0.5  303.15     train
# 19  BrC(Br)C(Br)Br  CCCCCCCCCCO  0.933013        0.6  303.15     train
#
#         type                      combos
# 0   original             B(Br)(Br)Br-CCO
# 1   original                    BrBr-CCO
# 2   original      BrC(Br)(Br)Br-c1ccccc1
# 3   original      BrC(Br)(Br)Br-c1ccccc1
# 4   original      BrC(Br)(Br)Br-c1ccccc1
# 5   original      BrC(Br)(Br)Br-c1ccccc1
# 6   original      BrC(Br)(Br)Br-c1ccccc1
# 7   original      BrC(Br)(Br)Br-c1ccccc1
# 8   original      BrC(Br)(Br)Br-c1ccccc1
# 9   original      BrC(Br)(Br)Br-c1ccccc1
# 10  original      BrC(Br)(Br)Br-c1ccccc1
# 11  original      BrC(Br)(Br)Br-c1ccccc1
# 12  original      BrC(Br)(Br)Br-c1ccccc1
# 13  original  BrC(Br)C(Br)Br-CCCCCCCCCCO
# 14  original  BrC(Br)C(Br)Br-CCCCCCCCCCO
# 15  original  BrC(Br)C(Br)Br-CCCCCCCCCCO
# 16  original  BrC(Br)C(Br)Br-CCCCCCCCCCO
# 17  original  BrC(Br)C(Br)Br-CCCCCCCCCCO
# 18  original  BrC(Br)C(Br)Br-CCCCCCCCCCO
# 19  original  BrC(Br)C(Br)Br-CCCCCCCCCCO

# %%
original_data.describe()
# Out:
#                logV     MolFrac_1             T
# count  40905.000000  40905.000000  40905.000000
# mean       0.071711      0.497873    305.477083
# std        0.406082      0.318345      6.210431
# min       -2.188234      0.000000    293.150000
# 25%       -0.218826      0.200000    298.428625
# 50%       -0.004557      0.500000    305.650000
# 75%        0.266937      0.800000    308.150000
# max        4.065026      1.000000    323.150000

# %%
# Check for data leakage between train and test sets
train_mol_1 = set(original_data[original_data['benchmark']== 'train']['MOL_1'])
test_mol_1 = set(original_data[original_data['benchmark']== 'test']['MOL_1'])
train_mol_2 = set(original_data[original_data['benchmark']== 'train']['MOL_2'])
test_mol_2 = set(original_data[original_data['benchmark']== 'test']['MOL_2'])

train_combos = set(original_data[original_data['benchmark']== 'train']['combos'])
test_combos = set(original_data[original_data['benchmark']== 'test']['combos'])

# Check if any MOL_1 from train is in test MOL_1 or MOL_2
leakage_mol_1 = train_mol_1.intersection(test_mol_1) | train_mol_1.intersection(test_mol_2)

# Check if any MOL_2 from train is in test MOL_1 or MOL_2
leakage_mol_2 = train_mol_2.intersection(test_mol_1) | train_mol_2.intersection(test_mol_2)

# Check if any combos from train is in test combos
leakage_combos = train_combos.intersection(test_combos)

# Print results
if leakage_mol_1:
    print(f"Data leakage found in MOL_1: {leakage_mol_1}")
else:
    print("No data leakage in MOL_1")

if leakage_mol_2:
    print(f"Data leakage found in MOL_2: {leakage_mol_2}")
else:
    print("No data leakage in MOL_2")

if leakage_combos:
    print(f"Data leakage found in combos: {leakage_combos}")
else:
    print("No data leakage in combos")
# Out:
# Data leakage found in MOL_1: {'COCCOCCOCCOCCOC', 'NCc1ccccc1', 'CC/C(C)=N/O', 'Oc1ccccc1Cl', 'c1ccc2ccccc2c1', 'Cc1ccccc1[N+](=O)[O-]', 'C=CCN=C=S', 'CCCCCCBr', 'CC(=O)O', 'Clc1ccccc1', 'c1ccc2c(c1)CCCC2', 'C=CC(=O)OC', 'NCCO', 'ClC(Cl)(Cl)Cl', 'CCCCCCCCCC(=O)OCC', 'CCC(C)N', 'COC(=O)CCCCl', 'CC(C)CC(C)(C)C', 'CCNCCO', 'OCCCl', 'OCc1ccccc1', 'Brc1ccccc1', 'CCC(O)CC', 'CCCCOCCOCCOCCCC', 'CCCCBr', 'CNCCO', 'CCOCCOCCOCCO', 'Clc1ccc(Cl)c(Cl)c1', 'CCOC(=O)CCC(=O)OCC', 'COCCOCCOCCOC', 'CCOCCOCCO', 'Cc1ccc(C)cc1', 'Cc1ccncc1', 'NC1CCCCC1', 'CCCCN(CCCC)CCCC', 'O=S(=O)(O)O', 'CC(O)CC
C(=O)OCc1ccccc1', 'CCCCOC(C)=O', 'NCCN', 'OCCOCCOCCOCCO', 'OCCOCCO', 'CCC(C)Cl', 'Clc1cccc2ccccc12', 'CCCCCCCCCCCC', 'ClC1CCCCC1', 'CC(=O)OC(C)=O', 'CN(C)c1ccccc1', 'CC(C)C(=O)O', 'CCCCCCCCO', 'Cc1ccccn1', 'CNC=O', 'COCCOCCOCCO', 'CCCCOP(=O)(OCCCC)OCCCC', 'ClC=C(Cl)Cl', 'CCCCCCCCC', 'CCOC(=O)OCC', 'CC(=O)CC(C)=O', 'Cc1cc(C)cc(C)c1', 'C=C1CCC2CC1C2(C)C', 'CCCCCCC(C)O', 'COc1ccc(C=O)cc1', 'C=CC(C)(O)CCC=C(C)C', 'Oc1ccccc1Cl', 'CC(=O)O', 'c1ccc2c(c1)CCCC2', 'NCCO', 'ClC(Cl)(Cl)Cl', 'CCCCCCCCCC(=O)OCC', 'CCC(C)N', 'C1CCC2CCCCC2C1', 'CC(C)CC(C)(C)C', 'CCNCCO', 'OCCCl', 'CNCCO', 'CCOCCOCCOCCO', 'CCOCCOCCO', 'Cc1ccc(C)cc1', 'CCCCN(CCCC)CCCC', 'CCc1ccccc1', 'CCCN', 'CCO', 'CCCNCCC', 'ClC(Cl)C(Cl)Cl', 'CCOC(C)=O', 'BrCCBr', 'CCCCCCCCCC(=O)OC', 'CC(O)CO', 'OCCCO', 'Cc1cccc(O)c1', 'CCCCCCCCCCO', 'CCCCCCCCN', 'ClCCl', 'CCCCC', 'Cc1ccccc1O', 'C1CCCCCCC1', 'CC1CCCCC1=O', 'OCCCCO', 'OCCc1ccccc1', 'O=C1CCCO1', 'OCCOCCOCCO', 'CN1CCNCC1', 'CCCCC(C)O', 'CO', 'CCCCCCCCCC', 'OCC(O)CO', 'COC(C)=O', 'CCCCCCCC', 'CCOCCOCCOCC', 'COC(=O)c1ccccc1', 'CCCCCCCO', 'O=C1CCCC1', 'CCCC(C)CO', 'CCN(CC)CC', 'CC(C)CCl', 'C1CCOC1', 'CC(=O)CC(C)(C)O', 'ClCCCl', 'CCCOC(C)=O', 'CC(C)OC(C)C', 'CCC(=O)CC', 'COc1ccccc1', 'CCCCCCC', 'Cc1ccc(C(C)C)cc1', 'Cc1ccccc1', 'CCCC(C)=O', 'CCCCOCCCC', 'CC(Cl)(Cl)Cl', 'CCNCC', 'CC(C)=O', 'CNc1ccccc1', 'CCCCCCN', 'Nc1ccccc1', 'C=CC#N', 'CCCCCCO', 'CCN(C=O)CC', 'C1COCCO1', 'CCCCO', 'c1ccccc1', 'COCCOCCOC', 'c1ccncc1', 'CC[N+](=O)[O-]', 'CCCCCl', 'Clc1ccccc1Cl', 'CC(C)C1CCCCC1'}
# No data leakage in combos

# %%
original_data
# Out:
#                MOL_1     MOL_2      logV  MolFrac_1       T benchmark  \
# 0        B(Br)(Br)Br       CCO -0.140112        1.0  298.00     train
# 1               BrBr       CCO -0.011187        1.0  298.00     train
# 2      BrC(Br)(Br)Br  c1ccccc1 -0.219755        0.0  298.15     train
# 3      BrC(Br)(Br)Br  c1ccccc1 -0.080765        0.1  298.15     train
# 4      BrC(Br)(Br)Br  c1ccccc1  0.050070        0.2  298.15     train
# ...              ...       ...       ...        ...     ...       ...
# 40900       c1ccncc1      CCCO -0.055304        0.6  308.15      test
# 40901       c1ccncc1      CCCO -0.073118        0.7  308.15      test
# 40902       c1ccncc1      CCCO -0.082963        0.8  308.15      test
# 40903       c1ccncc1      CCCO -0.091413        0.9  308.15      test
# 40904       c1ccncc1      CCCO -0.104440        1.0  308.15      test
#
#            type                  combos
# 0      original         B(Br)(Br)Br-CCO
# 1      original                BrBr-CCO
# 2      original  BrC(Br)(Br)Br-c1ccccc1
# 3      original  BrC(Br)(Br)Br-c1ccccc1
# 4      original  BrC(Br)(Br)Br-c1ccccc1
# ...         ...                     ...
# 40900  original           CCCO-c1ccncc1
# 40901  original           CCCO-c1ccncc1
# 40902  original           CCCO-c1ccncc1
# 40903  original           CCCO-c1ccncc1
# 40904  original           CCCO-c1ccncc1
#
# [40905 rows x 8 columns]

# %%
all_data_mirror = original_data.copy()
all_data_mirror['MOL_1_New'] = all_data_mirror['MOL_2']
all_data_mirror['MOL_2_New'] = all_data_mirror['MOL_1']
all_data_mirror['MolFrac_1_New'] = 1.0 - all_data_mirror['MolFrac_1']
all_data_mirror['type'] = 'expanded'

all_data_mirror = all_data_mirror.drop(columns=['MOL_1', 'MOL_2', 'MolFrac_1'])
all_data_mirror = all_data_mirror.rename(columns={'MOL_1_New': 'MOL_1', 'MOL_2_New': 'MOL_2', 'MolFrac_1_New': 'MolFrac_1'})

all_data_mirror = all_data_mirror[original_data.columns]

all_data_mirror.head(20)
# Out:
#           MOL_1           MOL_2      logV  MolFrac_1       T benchmark  \
# 0           CCO     B(Br)(Br)Br -0.140112        0.0  298.00     train
# 1           CCO            BrBr -0.011187        0.0  298.00     train
# 2      c1ccccc1   BrC(Br)(Br)Br -0.219755        1.0  298.15     train
# 3      c1ccccc1   BrC(Br)(Br)Br -0.080765        0.9  298.15     train
# 4      c1ccccc1   BrC(Br)(Br)Br  0.050070        0.8  298.15     train
# 5      c1ccccc1   BrC(Br)(Br)Br  0.165422        0.7  298.15     train
# 6      c1ccccc1   BrC(Br)(Br)Br  0.264700        0.6  298.15     train
# 7      c1ccccc1   BrC(Br)(Br)Br  0.349316        0.5  298.15     train
# 8      c1ccccc1   BrC(Br)(Br)Br  0.420879        0.4  298.15     train
# 9      c1ccccc1   BrC(Br)(Br)Br  0.480840        0.3  298.15     train
# 10     c1ccccc1   BrC(Br)(Br)Br  0.530328        0.2  298.15     train
# 11     c1ccccc1   BrC(Br)(Br)Br  0.570099        0.1  298.15     train
# 12     c1ccccc1   BrC(Br)(Br)Br  0.600592        0.0  298.15     train
# 13  CCCCCCCCCCO  BrC(Br)C(Br)Br  0.985696        1.0  303.15     train
# 14  CCCCCCCCCCO  BrC(Br)C(Br)Br  0.975610        0.9  303.15     train
# 15  CCCCCCCCCCO  BrC(Br)C(Br)Br  0.966143        0.8  303.15     train
# 16  CCCCCCCCCCO  BrC(Br)C(Br)Br  0.956663        0.7  303.15     train
# 17  CCCCCCCCCCO  BrC(Br)C(Br)Br  0.947683        0.6  303.15     train
# 18  CCCCCCCCCCO  BrC(Br)C(Br)Br  0.939620        0.5  303.15     train
# 19  CCCCCCCCCCO  BrC(Br)C(Br)Br  0.933013        0.4  303.15     train
#
#         type                      combos
# 0   expanded             B(Br)(Br)Br-CCO
# 1   expanded                    BrBr-CCO
# 2   expanded      BrC(Br)(Br)Br-c1ccccc1
# 3   expanded      BrC(Br)(Br)Br-c1ccccc1
# 4   expanded      BrC(Br)(Br)Br-c1ccccc1
# 5   expanded      BrC(Br)(Br)Br-c1ccccc1
# 6   expanded      BrC(Br)(Br)Br-c1ccccc1
# 7   expanded      BrC(Br)(Br)Br-c1ccccc1
# 8   expanded      BrC(Br)(Br)Br-c1ccccc1
# 9   expanded      BrC(Br)(Br)Br-c1ccccc1
# 10  expanded      BrC(Br)(Br)Br-c1ccccc1
# 11  expanded      BrC(Br)(Br)Br-c1ccccc1
# 12  expanded      BrC(Br)(Br)Br-c1ccccc1
# 13  expanded  BrC(Br)C(Br)Br-CCCCCCCCCCO
# 14  expanded  BrC(Br)C(Br)Br-CCCCCCCCCCO
# 15  expanded  BrC(Br)C(Br)Br-CCCCCCCCCCO
# 16  expanded  BrC(Br)C(Br)Br-CCCCCCCCCCO
# 17  expanded  BrC(Br)C(Br)Br-CCCCCCCCCCO
# 18  expanded  BrC(Br)C(Br)Br-CCCCCCCCCCO
# 19  expanded  BrC(Br)C(Br)Br-CCCCCCCCCCO

# %%
# combine original_data and all_data_mirror vertically
all_data = pd.concat([original_data, all_data_mirror], axis=0).reset_index(drop=True)

all_data
# Out:
#                MOL_1     MOL_2      logV  MolFrac_1       T benchmark  \
# 0        B(Br)(Br)Br       CCO -0.140112        1.0  298.00     train
# 1               BrBr       CCO -0.011187        1.0  298.00     train
# 2      BrC(Br)(Br)Br  c1ccccc1 -0.219755        0.0  298.15     train
# 3      BrC(Br)(Br)Br  c1ccccc1 -0.080765        0.1  298.15     train
# 4      BrC(Br)(Br)Br  c1ccccc1  0.050070        0.2  298.15     train
# ...              ...       ...       ...        ...     ...       ...
# 81805           CCCO  c1ccncc1 -0.055304        0.4  308.15      test
# 81806           CCCO  c1ccncc1 -0.073118        0.3  308.15      test
# 81807           CCCO  c1ccncc1 -0.082963        0.2  308.15      test
# 81808           CCCO  c1ccncc1 -0.091413        0.1  308.15      test
# 81809           CCCO  c1ccncc1 -0.104440        0.0  308.15      test
#
#            type                  combos
# 0      original         B(Br)(Br)Br-CCO
# 1      original                BrBr-CCO
# 2      original  BrC(Br)(Br)Br-c1ccccc1
# 3      original  BrC(Br)(Br)Br-c1ccccc1
# 4      original  BrC(Br)(Br)Br-c1ccccc1
# ...         ...                     ...
# 81805  expanded           CCCO-c1ccncc1
# 81806  expanded           CCCO-c1ccncc1
# 81807  expanded           CCCO-c1ccncc1
# 81808  expanded           CCCO-c1ccncc1
# 81809  expanded           CCCO-c1ccncc1
#
# [81810 rows x 8 columns]

# %%
all_data.to_csv(data_prefix + 'original_data.csv', index=False)
